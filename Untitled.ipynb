# %% [markdown]
# ## 30315 이정우

# %% [markdown]
# ## 주제 : 유형별 해양 사고 현황

# %% [markdown]
# - 출처 : https://www.data.go.kr/data/15007826/fileData.do

# %% [markdown]
# - 제공기관 : 해양경찰청
# - 분류체계 : 공고질서및 안전 - 해경
# - 관리부서 : 기동방제과
# - 기간 : 2005 ~ 2019

# %%
import pandas as pd
path=(r'C:\Users\user\Desktop\30315\해양경찰청 해양오염사고통계_20191231.csv')
path
# Out:
# 'C:\\Users\\user\\Desktop\\30315\\해양경찰청 해양오염사고통계_20191231.csv'

# %%
path
# Out:
# 'C:\\Users\\user\\Desktop\\30315\\해양경찰청 해양오염사고통계_20191231.csv'

# %%
df = pd.read_csv(path,encoding = 'cp949')

# %%
df
# Out:
#      기준년  부주의수(건수)  부주의유출량(kl)  해난수(건수)  고의수(건수)  고의유출량(kl)  파손수(건수)  \
# 0   2005       173          62      121       16          1       30
# 1   2006       117          12       73       14          1       74
# 2   2007       146          15      124       23          3       45
# 3   2008       141          39       62       13         52       22
# 4   2009       159          19       57       25         46       39
# 5   2010       195          94       67       26         17       34
# 6   2011       189          87       47       16        104       21
# 7   2012       171          93       33       12          1       27
# 8   2013       158         164       46       10          2       30
# 9   2014       124          22       35       10          2       29
# 10  2015       127          27       61       10          2       35
# 11  2016       122          30       80       17         55       42
# 12  2017       105          33       82       29         11       47
# ...

# %%
t=df.head(15)

# %%
t
# Out:
#      기준년  부주의수(건수)  부주의유출량(kl)  해난수(건수)  고의수(건수)  고의유출량(kl)  파손수(건수)  \
# 0   2005       173          62      121       16          1       30
# 1   2006       117          12       73       14          1       74
# 2   2007       146          15      124       23          3       45
# 3   2008       141          39       62       13         52       22
# 4   2009       159          19       57       25         46       39
# 5   2010       195          94       67       26         17       34
# 6   2011       189          87       47       16        104       21
# 7   2012       171          93       33       12          1       27
# 8   2013       158         164       46       10          2       30
# 9   2014       124          22       35       10          2       29
# 10  2015       127          27       61       10          2       35
# 11  2016       122          30       80       17         55       42
# 12  2017       105          33       82       29         11       47
# ...

# %%
a=t['기준년']

b=t['부주의수(건수)']
b1=t['해난수(건수)']
b2=t['고의수(건수)']
b3=t['파손수(건수)']
b4=t['기타수(건수)']

# %% [markdown]
# ## 년도에 따른 사고 건수

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
rc('font',family='gulim')
plt.title('사고 건수 통계')
plt.plot(a,b,'r--')
plt.plot(a,b1,'r--',color='blue')
plt.plot(a,b2,'r--',color='black')
plt.plot(a,b3,'r--',color='pink')
plt.plot(a,b4,'r--',color='green')
plt.legend(['부주의수(건수)','해난수(건수)','고의수(건수)','파손수(건수)','기타수(건수)'])
plt.ylabel('건수')
plt.xlabel('기준년')
# Out:
# Text(0.5, 0, '기준년')

# %% [markdown]
# ## 표에서 보다싶이 건수의 값이 년도가 지나갈수록 저렇게 변하는 것을 알수가 있다.

# %%
df
# Out:
#      기준년  부주의수(건수)  부주의유출량(kl)  해난수(건수)  고의수(건수)  고의유출량(kl)  파손수(건수)  \
# 0   2005       173          62      121       16          1       30
# 1   2006       117          12       73       14          1       74
# 2   2007       146          15      124       23          3       45
# 3   2008       141          39       62       13         52       22
# 4   2009       159          19       57       25         46       39
# 5   2010       195          94       67       26         17       34
# 6   2011       189          87       47       16        104       21
# 7   2012       171          93       33       12          1       27
# 8   2013       158         164       46       10          2       30
# 9   2014       124          22       35       10          2       29
# 10  2015       127          27       61       10          2       35
# 11  2016       122          30       80       17         55       42
# 12  2017       105          33       82       29         11       47
# ...

# %%
c=t['부주의유출량(kl)']
c1=t['고의유출량(kl)']
c2=t['파손유출량(kl)']
c3=t['기타유출량(kl)']

# %% [markdown]
# ## 년도에 따른 유출량

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
rc('font',family='gulim')
plt.title('사고 유출량 통계')
plt.plot(a,c,'r--')
plt.plot(a,c1,'r--',color='blue')
plt.plot(a,c2,'r--',color='black')
plt.plot(a,c3,'r--',color='pink')
plt.legend(['부주의유출량(kl)','고의유출량(kl)','파손유출량(kl)','기타유출량(kl)'])
plt.ylabel('유출량')
plt.xlabel('기준년')
# Out:
# Text(0.5, 0, '기준년')

# %% [markdown]
# ## 유출량이 연도가 지날수록 2010년쯤에 잠잔해지다가 확 올라가는 추세가 보인다.
